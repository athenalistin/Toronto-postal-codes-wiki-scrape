# %%
# !pip install beautifulsoup4 as bs4
# Out:
# Collecting beautifulsoup4
#   Downloading https://files.pythonhosted.org/packages/66/25/ff030e2437265616a1e9b25ccc864e0371a0bc3adb7c5a404fd661c6f4f6/beautifulsoup4-4.9.1-py3-none-any.whl (115kB)
#      |████████████████████████████████| 122kB 6.3MB/s eta 0:00:01
# Collecting as
#   Downloading https://files.pythonhosted.org/packages/b4/08/226c133ec497d25a63edb38527c02db093c7d89e6d4cdc91078834486a5d/as-0.1-py3-none-any.whl
# Collecting bs4
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Downloading https://files.pythonhosted.org/packages/6f/8f/457f4a5390eeae1cc3aeab89deb7724c965be841ffca6cfca9197482e470/soupsieve-2.0.1-py3-none-any.whl
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, as, bs4
# Successfully installed as-0.1 beautifulsoup4-4.9.1 bs4-0.0.1 soupsieve-2.0.1

# %%
from bs4 import BeautifulSoup as soup
import requests
import pandas as pd
import numpy as np

# %%
# download data in the url
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
rawtext = requests.get(url).text
dsoup = soup(rawtext, "html.parser")

#finding the table element
toronto = dsoup.find('table', class_='wikitable sortable')

# %%
#table clean
dt = []
for row in toronto.find_all('tr'):
    col = row.find_all('td')
    if len(col) == 3:
        dt.append((col[0].text.strip(), col[1].text.strip(), col[2].text.strip()))
        
#into dataframe
df = pd.DataFrame(np.asarray(dt))
df.columns = ['PostalCode', 'Borough', 'Neighborhood']

df['Neighborhood'] = df['Neighborhood'].str.replace(']', '')

df.replace('Not assigned', np.nan, inplace=True)

df.head(10)
# Out:
#   PostalCode           Borough                                 Neighborhood
# 0        M1A               NaN                                          NaN
# 1        M2A               NaN                                          NaN
# 2        M3A        North York                                    Parkwoods
# 3        M4A        North York                             Victoria Village
# 4        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5        M6A        North York             Lawrence Manor, Lawrence Heights
# 6        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 7        M8A               NaN                                          NaN
# 8        M9A         Etobicoke      Islington Avenue, Humber Valley Village
# 9        M1B       Scarborough                               Malvern, Rouge

# %% [markdown]
# The next step is to add neighbourhood to a borough where a neighborhood is Not assigned (NaN).

# %%
n = len(df.index)
for i in range(0, n):
    if df.iloc[i,1] is not np.nan and df.iloc[i,2] is np.nan:
        df.iloc[i,2] = df.iloc[i,1]
df.head(10)
# Out:
#   PostalCode           Borough                                 Neighborhood
# 0        M1A               NaN                                          NaN
# 1        M2A               NaN                                          NaN
# 2        M3A        North York                                    Parkwoods
# 3        M4A        North York                             Victoria Village
# 4        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5        M6A        North York             Lawrence Manor, Lawrence Heights
# 6        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 7        M8A               NaN                                          NaN
# 8        M9A         Etobicoke      Islington Avenue, Humber Valley Village
# 9        M1B       Scarborough                               Malvern, Rouge

# %% [markdown]
# Next step: Dropping not assigned boroughs

# %%
df.dropna(inplace=True)

# %% [markdown]
# Final step in cleaning: grouping neighborhoods in the same borough separated by commas

# %%
df = df.groupby(['PostalCode', 'Borough'])['Neighborhood'].apply(', '.join).reset_index()
df.head(10)
# Out:
#   PostalCode      Borough                                     Neighborhood
# 0        M1B  Scarborough                                   Malvern, Rouge
# 1        M1C  Scarborough           Rouge Hill, Port Union, Highland Creek
# 2        M1E  Scarborough                Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                           Woburn
# 4        M1H  Scarborough                                        Cedarbrae
# 5        M1J  Scarborough                              Scarborough Village
# 6        M1K  Scarborough      Kennedy Park, Ionview, East Birchmount Park
# 7        M1L  Scarborough                  Golden Mile, Clairlea, Oakridge
# 8        M1M  Scarborough  Cliffside, Cliffcrest, Scarborough Village West
# 9        M1N  Scarborough                      Birch Cliff, Cliffside West

# %%
print (df.shape)
# Out:
# (103, 3)

# %%
# !wget -O Geospatial_Coordinates.csv http://cocl.us/Geospatial_data
# Out:
# --2020-06-17 16:56:28--  http://cocl.us/Geospatial_data
# Resolving cocl.us (cocl.us)... 169.48.113.194, 158.85.108.86, 158.85.108.83
# Connecting to cocl.us (cocl.us)|169.48.113.194|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cocl.us/Geospatial_data [following]
# --2020-06-17 16:56:28--  https://cocl.us/Geospatial_data
# Connecting to cocl.us (cocl.us)|169.48.113.194|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-06-17 16:56:31--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.29.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.29.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-06-17 16:56:31--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-06-17 16:56:31--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 107.152.27.211
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|107.152.27.211|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!zXAFuQuH82P7olFI02py1OaRx5Rf6m1fWiTKxp9C1ULKAeFg2eNEC28xj4TZF0DRkFSkzQMXRtajQckVs-fpMC7HcUaO7zKJiEa0BYbtkOQqph7a-qqbt5_UwqqxMxEq2F6BysFLFHCT0SLQ9YzDkwk63V6Ii1ARSbJ7J1SyO0Jj5KsvHneRYdIfJdVnFA6Sc7bnKfIm1nQfKa21xgCSNLiJ6K-6ZFvNUU_wWW5TnDVYy_Rpw-Ka2k5IL6_NDnuDfJdgOrK6sybBwvaKzkmhzTNHu3kHBZMDQdeF-kFtMN0I0djnna17KUH8QvoKvukB2Mxq4qzLzUqQgAAIp--0DBoXDqsmom_OvuhWG_c5BpwnPVSoZ2sCwTjUW4IsFlGAiG314QfBOaLsmXTE0GOKYoQNsxNvBgq3bYD3xLsJtFRM_E-17mX7-LfRKU1JsbhSETkQOBSEK0U7MGnN7d_IShd_VyxY36xMGyq7tiBllYNkK7O4d10EYlUO90zIQTkaEasx-Ls_Fpn79ZJL7f_9jG3D7YWpxv7rNJIExfOIdSQ8baw8CSKXJw8Hr3HIivJRUX3UdYRYExk2PGx4Lei1j667gNACW-LaUPXEiUGN9f3WfED9prvK5fKOcdnxv3lgU9IS3jtHCYYNtIbQxGploV4V53RPJXTGdQn1zgA9b4ycCbL4oC2jGxRd0W38-qdNwYeMGqvWc25wSJgYs1MR3HW57U715k-P4S9g7uBHOG--2wVnIrPTxIddF5ZJNDvk4IvwDLpQl-B6oLN_K-xraeJwk0Ry_znvGzNG5kqJwpdy3MfaOui99mjBGbELTCI9pyqdImbXfbbNmM5x9Qj0GVNJ6E5hTKQNNBfwGCMDBq-jAUidS6wyLVzmvuiCcrZmuJnhSBasvjwQUEasXu0GzmumwajZTyTHQGGqgZJil-apaMS2tkVr-2QMH1IlCPDnd4J4urNk8M7EUIadV2UQmVnKVLdzW-BU9rpwphMkB-SVn8_9rOkO5bLLxrqOrVwGiN7TEcSJR7iOs6RNv8zaSieDCC5k92_saAye2OPyAT8T5KUtWGT